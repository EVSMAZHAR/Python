# %% [markdown]
# # Chapter 30: Files & Folders I/O

# %% [raw]
# Parameter            Details
# filename         the path to your file or, if the file is in the working directory, the filename of your file
# access_mode     a string value that determines how the file is opened
# buffering       an integer value used for optional line buffering

# %% [markdown]
# ## File modes

# %% [markdown]
# There are different modes you can open a file with, specified by the mode parameter. These include:

# %% [markdown]
# - 'r' - reading mode. The default. It allows you only to read the file, not to modify it. When using this mode the file must exist.
# - 'w' - writing mode. It will create a new file if it does not exist, otherwise will erase the file and allow you to write to it.
# - 'a' - append mode. It will write data to the end of the file. It does not erase the file, and the file must exist for this mode.
# - 'rb' - reading mode in binary. This is similar to r except that the reading is forced in binary mode. This is also a default choice.
# - 'r+' - reading mode plus writing mode at the same time. This allows you to read and write into files at the same time without having to use r and w.
# - 'rb+' - reading and writing mode in binary. The same as r+ except the data is in binary
# - 'wb' - writing mode in binary. The same as w except the data is in binary.
# - 'w+' - writing and reading mode. The exact same as r+ but if the file does not exist, a new one is made. Otherwise, the file is overwritten.
# - 'wb+' - writing and reading mode in binary mode. The same as w+ but the data is in binary.
# - 'ab' - appending in binary mode. Similar to a except that the data is in binary.
# - 'a+' - appending and reading mode. Similar to w+ as it will create a new file if the file does not exist. Otherwise, the file pointer is at the end of the file if it exists.
# - 'ab+' - appending and reading mode in binary. The same as a+ except that the data is in binary.

# %%
with open(filename, 'r') as f:
    f.read()
with open(filename, 'w') as f:
    f.write(filedata)
with open(filename, 'a') as f:
    f.write('\\n' + newdata)

# %% [markdown]
# Python 3 added a new mode for exclusive creation so that you will not accidentally truncate or overwrite and
# existing file.

# %% [markdown]
# - 'x' - open for exclusive creation, will raise FileExistsError if the file already exists
# - 'xb' - open for exclusive creation writing mode in binary. The same as x except the data is in binary.
# - 'x+' - reading and writing mode. Similar to w+ as it will create a new file if the file does not exist. Otherwise,will raise FileExistsError.
# - 'xb+' - writing and reading mode. The exact same as x+ but the data is binary

# %%
# Allow one to write your file open code in a more pythonic manner:
try:
    with open("fname", "r") as fout:
        pass
        # Work with your open file
except FileExistsError:
    print(FileExistsError)
    # Your error handling goes here

# %% [markdown]
# ## Reading a file line-by-line

# %%
#The simplest way to iterate over a file line-by-line:
with open('shoppinglist.txt', 'r') as fp:
    for line in fp:
        print(line)
# Out:
# tomato
#
# pasta
#
# garlic

# %%
# readline() allows for more granular control over line-by-line iteration. The example below is equivalent to the one above:
with open('shoppinglist.txt', 'r') as fp:
    while True:
        cur_line = fp.readline()
        # If the result is an empty string
        if cur_line == '':
        # We have reached the end of the file
            break
        print(cur_line)
# Out:
# tomato
#
# pasta
#
# garlic

# %% [markdown]
# ## Iterate files (recursively)

# %% [markdown]
# To iterate all files, including in sub directories, use os.walk:

# %%
import os
for root, folders, files in os.walk('.'):
    for filename in files:
        print(root, filename)
# Out:
# . Chapter 1 Get started with Python Language.ipynb
# . Chapter 10 Bitwise Operators.ipynb
# . Chapter 11 Boolean Operators .ipynb
# . Chapter 12 Operator Precedence.ipynb
# . Chapter 13 Variable Scope and Binding.ipynb
# . Chapter 14 Conditionals.ipynb
# . Chapter 15 Comparisons.ipynb
# . Chapter 16 Loops.ipynb
# . Chapter 17 Arrays.ipynb
# . Chapter 18 Multidimensional arrays.ipynb
# . Chapter 19 Dictionary.ipynb
# . Chapter 2  Python Data Types.ipynb
# . Chapter 20 List.ipynb
# . Chapter 21 List comprehensions.ipynb
# . Chapter 22 List slicing (selecting parts of lists).ipynb
# . Chapter 23 groupby().ipynb
# . Chapter 24 Linked lists.ipynb
# . Chapter 26 Filter.ipynb
# . Chapter 27 Heapq.ipynb
# . Chapter 28 Tuple.ipynb
# . Chapter 29 Basic Input and Output.ipynb
# . Chapter 3 Indentation.ipynb
# . Chapter 30 Files & Folders IO.ipynb
# . Chapter 4 Comments and Documentation.ipynb
# . Chapter 5 Date and Time.ipynb
# . Chapter 6 Date Formatting.ipynb
# . Chapter 7 Enum.ipynb
# . Chapter 8 Set.ipynb
# . Chapter 9 Simple Mathematical Operators.ipynb
# . hello.ipynb
# . hello.py
# . README.md
# . shoppinglist.txt
# . untitled.txt
# .\.git .MERGE_MSG.swp
# .\.git COMMIT_EDITMSG
# .\.git config
# .\.git description
# .\.git FETCH_HEAD
# .\.git HEAD
# .\.git index
# .\.git ORIG_HEAD
# .\.git packed-refs
# .\.git smartgit.config
# .\.git\hooks applypatch-msg.sample
# .\.git\hooks commit-msg.sample
# .\.git\hooks fsmonitor-watchman.sample
# .\.git\hooks post-update.sample
# .\.git\hooks pre-applypatch.sample
# .\.git\hooks pre-commit.sample
# .\.git\hooks pre-merge-commit.sample
# .\.git\hooks pre-push.sample
# .\.git\hooks pre-rebase.sample
# .\.git\hooks pre-receive.sample
# .\.git\hooks prepare-commit-msg.sample
# .\.git\hooks update.sample
# .\.git\info exclude
# .\.git\logs HEAD
# .\.git\logs\refs\heads master
# .\.git\logs\refs\remotes\origin HEAD
# .\.git\logs\refs\remotes\origin master
# .\.git\objects\02 f1f0e8c8d23de7a2b106388908ae0f91e2d1d0
# .\.git\objects\05 ad3efc606c45391f7b96960b5b633b689dc514
# .\.git\objects\0c cc8dcd9ce69e5149727cdd53679d1c5fd4ddde
# .\.git\objects\0e cefa61fefd5ff92008978137762f87bfc1b564
# .\.git\objects\16 2669c834515c83d302cd17c8bfb0dbacf55b87
# .\.git\objects\18 27d98e1beb001916f6b4b6ee71d333d1b4f78b
# .\.git\objects\1c 8cbb363c0931a1e26b53bf40dad5101eea9ebc
# .\.git\objects\1e db4abc6b73d5328fd5c9f95fc3f0808fa2473c
# .\.git\objects\20 75fb2bdbda9eee8d86b0d1756ed6dda5a0f4c1
# .\.git\objects\20 cfbaf91bb19e13af19b66b0ed42bb82e38257f
# .\.git\objects\21 68464dd72841b52bfe4b3328dfe341b97f97b1
# .\.git\objects\22 2c65b5d2e5b82cfd44edd5e3a40d3290b0793e
# .\.git\objects\2d 4be019d49e7fa7bd74d890d0f737215510ccae
# .\.git\objects\2d d77854befbb7a1a9c4397bb274d87d7b8a6b81
# .\.git\objects\2f c7881e80f6d05d971d3028c7b935eedf1125ab
# .\.git\objects\30 fbe9f90687c9864f0fc45d58e99d4a295ddaa5
# .\.git\objects\34 dfec471140f3fa1b6428fe873736fd7d8c4c0d
# .\.git\objects\38 6ab5f833b52d202548a84d2b6044f13158f5f2
# .\.git\objects\3a 5465492a2c567331c6a65a1a2f9f95052a5b6f
# .\.git\objects\3c 5ba73ba013751292251d3c5d17721aee28b1b4
# .\.git\objects\3c e3b4d7ad343a73a5e1974f11b9b22cf11aad8a
# .\.git\objects\42 2222595290ab4878861a7f7b82d91e9dcf0fc2
# .\.git\objects\42 5a78db9f475cd06c24102590dc82d08783d1ba
# .\.git\objects\44 3ac1d7cb6554adbfc531ac8b15b6d5c0d5b7c9
# .\.git\objects\44 ecb38a720ebdd6cbd6986078b888592bfab854
# .\.git\objects\45 bc5df042ad479289305d3e6464ecdf32fbbee7
# .\.git\objects\47 a39f923f05a30e67198d022255fedb837747e5
# .\.git\objects\47 f75f22c3231680977c7d02630e2a261ac2014e
# .\.git\objects\4a 88176f23a0198a2270096f825248dcc57d68ac
# .\.git\objects\4e c762711994eba2c09a3b96e284ec07ee92051e
# .\.git\objects\56 d6fe1dc1ef1793a04f3bf0764cc804a7c85399
# .\.git\objects\57 e1b9c63682676755db204b7731c1a29a5ad516
# .\.git\objects\62 98dd7faad27b4c6782b8057fc6c390dbc90bfa
# .\.git\objects\6d e5b420949285ae22312957f49d1477329abb6a
# .\.git\objects\6e 595f58bfbeb1c19ab71c53e83335574c8521ef
# .\.git\objects\77 c99508459e937ad5c0c571d2767c862ad030d3
# .\.git\objects\78 ab6aee731511c46aa85dd7e7639f588750cbc8
# .\.git\objects\7a e96cd06ffc25bd38e590f4a3cec967ea5a396c
# .\.git\objects\7b a3ecccd86103491403745322849404c23aac83
# .\.git\objects\7b c41429b1df072c7f738614a49c7b6f87ce2175
# .\.git\objects\7b c482982f90a05ea02f481f7c7dc6eafd6d70fe
# .\.git\objects\7f ec51502cbc3200b3d0ffc6bbba1fe85e197f3d
# .\.git\objects\8b cc81ad156567ef1c94c6f0251fe7c033f93e46
# .\.git\objects\8c edfb21815c9408609279721b15f291cdc1b4f4
# .\.git\objects\94 e1beca8e6d05c79bb3af5fa1286765d59c1e3a
# .\.git\objects\9a ea6286876a787a711b2310bc70cf72b46b5104
# .\.git\objects\9c bd23849be4d0ccc13b9b372fd467036e560ac2
# .\.git\objects\9f dc083c349218aad1ffc6f9a93301ce5dd8be82
# .\.git\objects\a1 d4eb24c1d1b22605c805ed39b78bb47c90679a
# .\.git\objects\a3 850822aab9b9984cb0d4b289520e52801828bd
# .\.git\objects\a4 1b4062ddbe531ac4fe21836800069dfc1c2350
# .\.git\objects\a4 ac903f7a3af70c794c4eae9b261a2d4454610b
# .\.git\objects\a7 4260b25b658b4ed277d1ce28beb3b0f237ab74
# .\.git\objects\a7 486eae94ac70bd3fc0144172b80cc37ae2ec9b
# .\.git\objects\ac 48e5bcde4181971f30edf5458d825518e6805a
# .\.git\objects\ae eef1a4e5204fd8dfa9704a592c09c0bf861fb5
# .\.git\objects\af b1bcb2d6b3f1f408b02500cdc043fe80aeb86e
# .\.git\objects\b1 0f38606d420df52f5b7a3989d9b74e3ac7e14c
# .\.git\objects\b6 1b0f7113553b8c964b28aa6766e19a50387ade
# .\.git\objects\b7 754a85698ecec3b1acf6a3e8317e1eea0b308d
# .\.git\objects\b9 6e9813674f2d9331df79b126cde31039ceed66
# .\.git\objects\c6 cc05bdefb666a78c507400590d387446b0c6dc
# .\.git\objects\cc ee5615ddd299f2be15eeeb1fcf62ba6ad16ecc
# .\.git\objects\cf 7104da99ad412772e27ca35870484058af94ba
# .\.git\objects\d1 187a004ba03352871438cdce57ef949a60e27c
# .\.git\objects\d1 de1a83ccb6802c83f6681796aa2ac54033a44c
# .\.git\objects\d5 d0d018db6d2b8d2ec2f7431fa21008371c1d24
# .\.git\objects\dc ffc5beb3d30522b2e5ba8e1acc5f14cb04fbee
# .\.git\objects\dd 1780cda777ded133031584e367ae61a8b1d61c
# .\.git\objects\df 89559d1b94a72ce898d0cfeda4966a6d06a901
# .\.git\objects\e0 aa5d141e7a52cbd24f09fff6dc69eb498fc1a6
# .\.git\objects\e0 dfa60d5a5c07315721296efaf2386157d06182
# .\.git\objects\e2 64bc6d2af25c9bd1b2bce324c9a497a356a937
# .\.git\objects\f3 6b371363dd49bec4ee0f66f282c13f970d927a
# .\.git\objects\f3 951ebd29fe6fe1ed98e1c9e2c3325142d8b7aa
# .\.git\objects\fc db16d47447a87f048a5c45267d9ae292d00f71
# .\.git\objects\ff b6aff844a186edd98088bcdedb0e1604d4851e
# .\.git\refs\heads master
# .\.git\refs\remotes\origin HEAD
# .\.git\refs\remotes\origin master
# .\.git\smartgit\logcache nodes.uuid
# .\.git\smartgit\logcache nodes2
# .\.ipynb_checkpoints Chapter 1 Get started with Python Language-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 14 Conditionals-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 15 Comparisons-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 16 Loops-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 17 Arrays-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 18 Multidimensional arrays-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 19 Dictionary-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 2  Python Data Types-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 20 List-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 21 List comprehensions-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 22 List slicing (selecting parts of lists)-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 23 groupby()-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 24 Linked lists-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 26 Filter-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 27 Heapq-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 28 Tuple-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 29 Basic Input and Output-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 3 Indentation-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 30 Files & Folders IO-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 4 Comments and Documentation-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 5 Date and Time-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 6 Date Formatting-checkpoint.ipynb
# .\.ipynb_checkpoints Chapter 7 Enum-checkpoint.ipynb
# .\.ipynb_checkpoints hello-checkpoint.ipynb
# .\__pycache__ hello.cpython-38.pyc

# %%
import os
for root, folders, files in os.walk('.'):
    for filename in files:
        #print(root, filename)
        with open(filename ,'rb') as file:
            lines = file.readlines()
            print(lines)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 18: Multidimensional arrays / Lists"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "### Lists in lists"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "A good way to visualize a 2d array is as a list of lists. Something like this:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[[1, 2, 3], [4, 5, 6], [7, 8, 9]]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 1,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "lst=[[1,2,3],[4,5,6],[7,8,9]]\\n",\n', b'    "lst"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "here the outer list lst has three things in it. each of those things is another list: The first one is: [1,2,3], the second\\n",\n', b'    "one is: [4,5,6] and the third one is: [7,8,9]. You can access these lists the same way you would access another\\n",\n', b'    "other element of a list, like this:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[1, 2, 3]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print (lst[0])\\n"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 3,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[4, 5, 6]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print (lst[1])\\n"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 5,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[7, 8, 9]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print (lst[2])\\n"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "You can then access the different elements in each of those lists the same way:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 6,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "1\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print (lst[0][0])"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 7,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "2\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print (lst[0][1])"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "You can also set values inside these lists the same way:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 8,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[[10, 11, 12], [4, 5, 6], [7, 8, 9]]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 8,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n',  ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 19: Dictionary"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Parameter Details\\n",\n', b'    "key      The desired key to lookup\\n",\n', b'    "value    The value to set or return"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "### Introduction to Dictionary"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "A dictionary is an example of a key value store also known as Mapping in Python. It allows you to store and retrieve\\n",\n', b'    "elements by referencing a key. As dictionaries are referenced by key, they have very fast lookups. As they are\\n",\n', b'    "primarily used for referencing items by key, they are not sorted."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "### creating a dict"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Dictionaries can be initiated in many ways:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "#### literal syntax"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "{\'key\': \'value\'}"\n', b'      ]\n', b'     },\n', b'     "execution_count": 1,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "d = {} \\n",\n', b'    "d = {\'key\': \'value\'}\\n",\n', b'    "d"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "#### dict comprehension"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "{\'key\': \'value\'}"\n', b'      ]\n', b'     },\n', b'     "execution_count": 2,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "d = {k:v for k,v in [(\'key\', \'value\',)]}\\n",\n', b'    "d"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 5,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "{\'key1\': \'value1\', \'key2\': \'value2\', \'key3\': \'value3\'}"\n', b'      ]\n', b'     },\n', b'     "execution_count": 5,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "d = {k:v for k,v in [(\'key1\', \'value1\'),(\'key2\', \'value2\'),(\'key3\', \'value3\')]}\\n",\n', b'    "d"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "#### built-in class: dict()"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 6,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "{\'key\': \'value\'}"\n', b'      ]\n', b'     },\n', b'     "execution_count": 6,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "d = dict() \\n",\n', b'    "d = dict(key=\'value\')\\n",\n', b'    "d"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 7,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "te ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Chapter 2: Python Data Types"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "### Data Types in Python"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Every value in Python has a datatype. Since everything is an object in Python programming, data types are actually classes and variables are instance (object) of these classes.\\n",\n', b'    "\\n",\n', b'    "There are various data types in Python. Some of the important types are listed below."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "<class \'str\'>\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "a_str = \'Hello World\'\\n",\n', b'    "print(str)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "H\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print(a_str[0])"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "Hello\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print(a_str[0:5])"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Set Data Types"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 5,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "{\'banana\', \'apple\', \'pear\', \'orange\'}\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "basket = {\'apple\', \'orange\', \'apple\', \'pear\', \'orange\', \'banana\'}\\n",\n', b'    "print(basket)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 7,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "{\'d\', \'c\', \'a\', \'r\', \'b\'}\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "a = set(\'abracadabra\')\\n",\n', b'    "print(a)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 8,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "{\'d\', \'c\', \'z\', \'a\', \'r\', \'b\'}\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "a.add(\'z\')\\n",\n', b'    "print(a)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 9,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "frozenset({\'d\', \'f\', \'s\', \'g\', \'a\'})\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "b = frozenset(\'asdfagsa\')\\n",\n', b'    "print(b)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 10,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "frozenset({\'Freiburg\', \'Frankfurt\', \'Basel\'})\\n"\n', b'     ]\n', b' ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Chapter 20: List"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "The Python List is a general data structure widely used in Python programs. They are found in other languages,\\n",\n', b'    "often referred to as dynamic arrays. They are both mutable and a sequence data type that allows them to be indexed\\n",\n', b'    "and sliced. The list can contain different types of objects, including other list objects."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## List methods and supported operators"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 2, 3, 4, 5]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 1,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# append\\n",\n', b'    "a = [1, 2, 3, 4, 5]\\n",\n', b'    "a"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 2, 3, 4, 5, 6, 7, 7]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 2,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "a.append(6)\\n",\n', b'    "a.append(7)\\n",\n', b'    "a.append(7)\\n",\n', b'    "a"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 3,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 2, 3, 4, 5, 6, 7, 7, [8, 9]]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 3,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "b = [8, 9]\\n",\n', b'    "a.append(b)\\n",\n', b'    "a"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 2, 3, 4, 5, 6, 7, 7, [8, 9], \'hello world\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 4,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "my_string = \\"hello world\\"\\n",\n', b'    "a.append(my_string)\\n",\n', b'    "a"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 5,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 2, 3, 4, 5, 6, 7, 7, 8, 9, 10]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 5,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# extend\\n",\n', b'    "a = [1, 2, 3, 4, 5, 6, 7, 7]\\n",\n', b'    "b = [8, 9, 10]\\n",\n', b'    "a.extend(b)\\n",\n', b'    "a"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 6,\n', b'   "metadata": {},\n', b'   "outputs": [],\n', b'   "source": [\n', b'    "a.extend(range(3))"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 7,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 2, 3, 4, 5, 6, 7, 7, 8, 9, 10, 0, 1, 2]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 7,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'    ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 21: List comprehensions"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "List comprehensions are used for creating new lists from other iterables."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "As list comprehensions return lists, they consist of brackets containing the expression, which is executed for each element along with the for loop to iterate over each element."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "raw",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "new_list = [expression for_loop_one_or_more conditions]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 4, 9, 16]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 1,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "#exampl without comprehension\\n",\n', b'    "numbers = [1, 2, 3, 4]\\n",\n', b'    "squares = []\\n",\n', b'    "for n in numbers:\\n",\n', b'    "  squares.append(n**2)\\n",\n', b'    "\\n",\n', b'    "squares"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 4, 9, 16]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 2,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# example using comprehesion\\n",\n', b'    "numbers = [1, 2, 3, 4]\\n",\n', b'    "squares = [n**2 for n in numbers]\\n",\n', b'    "squares"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Here, square brackets signify that the output is a list. n**2 is the expression executed for each element and for n in numbers is used to iterate over each element. In other words, execute n**2 (expression) for each element in numbers."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 3,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[2, 3, 4]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "#Find common numbers from two lists using for loop.\\n",\n', b'    "list_a = [1, 2, 3, 4]\\n",\n', b'    "list_b = [2, 3, 4, 5]\\n",\n', b'    "\\n",\n', b'    "common_num = []\\n",\n', b'    "\\n",\n', b'    "for a in list_a:\\n",\n', b'    "  for b in list_b:\\n",\n', b'    "    if a == b:\\n",\n', b'    "      common_num.append(a)\\n",\n', b'    "      \\n",\n', b'    "print(common_num)  "\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[2, 3, 4]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 4,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "#Find common numbers from two lists using list comprehension:\\n",\n', b'    "list_a = [1, 2, 3, 4]\\n",\n', b'    "list_b = [2, 3, 4, 5]\\n",\n', b'    "\\n",\n', b'    "common_num = []\\n",\n', b'    "\\n",\n', b'    "common_num = [a for a in list_a for b in list_b if a == b]\\n",\n', b'    "common_num\\n",\n', b'    " "\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 8,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'   ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 22: List slicing (selecting parts of lists)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'a\', \'c\', \'e\', \'g\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 1,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# slice by 2 step \\n",\n', b'    "lst = [\'a\', \'b\', \'c\', \'d\', \'e\', \'f\', \'g\', \'h\']\\n",\n', b'    "lst[::2]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'c\', \'d\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 2,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# slice list by range\\n",\n', b'    "lst = [\'a\', \'b\', \'c\', \'d\', \'e\']\\n",\n', b'    "lst[2:4]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 3,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'a\', \'b\', \'c\', \'d\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 3,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "lst[0:4]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'a\', \'b\', \'c\', \'d\', \'e\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 4,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "lst[0:]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 5,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'a\', \'b\', \'c\', \'d\', \'e\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 5,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "lst[:6]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 7,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[5, 4, 3, 2, 1]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 7,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "#Reversing a list with slicing\\n",\n', b'    "a = [1, 2, 3, 4, 5]\\n",\n', b'    "b= a[::-1]\\n",\n', b'    "b"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 8,\n', b'   "metadata": {},\n', b'   "outputs": [],\n', b'   "source": [\n', b'    "a.reverse()"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 9,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[5, 4, 3, 2, 1]"\n', b'      ]\n', b'     },\n', b'     "execution_count": 9,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "a"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "### Shifting a list using slicing"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 10,\n', b'   " ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 23: groupby()"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "raw",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Parameter Details\\n",\n', b'    "iterable   Any python iterable\\n",\n', b'    "key       Function(criteria) on which to group the iterable"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "In Python, the itertools.groupby() method allows developers to group values of an iterable class based on a\\n",\n', b'    "specified property into another iterable set of values."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "{\'animal\': [(\'animal\', \'bear\'), (\'animal\', \'duck\')],\\n",\n', b'       " \'plant\': [(\'plant\', \'cactus\')],\\n",\n', b'       " \'vehicle\': [(\'vehicle\', \'harley\'),\\n",\n', b'       "  (\'vehicle\', \'speed boat\'),\\n",\n', b'       "  (\'vehicle\', \'school bus\')]}"\n', b'      ]\n', b'     },\n', b'     "execution_count": 4,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "from itertools import *\\n",\n', b'    "things = [(\\"animal\\", \\"bear\\"), (\\"animal\\", \\"duck\\"), (\\"plant\\", \\"cactus\\"), (\\"vehicle\\", \\"harley\\"), \\n",\n', b'    "(\\"vehicle\\", \\"speed boat\\"), (\\"vehicle\\", \\"school bus\\")]\\n",\n', b'    "\\n",\n', b'    "dic = {}\\n",\n', b'    "f = lambda x: x[0]\\n",\n', b'    "for key, group in groupby(sorted(things, key=f), f):\\n",\n', b'    "    dic[key] = list(group)\\n",\n', b'    "dic"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 5,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "{\'animal\': [(\'animal\', \'bear\'), (\'animal\', \'duck\')],\\n",\n', b'       " \'plant\': [(\'plant\', \'cactus\')],\\n",\n', b'       " \'vehicle\': [(\'vehicle\', \'harley\'),\\n",\n', b'       "  (\'vehicle\', \'speed boat\'),\\n",\n', b'       "  (\'vehicle\', \'school bus\')]}"\n', b'      ]\n', b'     },\n', b'     "execution_count": 5,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "dic = {}\\n",\n', b'    "f = lambda x: x[0]\\n",\n', b'    "for key, group in groupby(things, f):\\n",\n', b'    "    dic[key] = list(group)\\n",\n', b'    "dic"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 7,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "{\'animal\': [[\'animal\', \'bear\'], [\'animal\', \'duck\']],\\n",\n', b'       " \'vehicle\': [[\'vehicle\', \'speed boat\'], [\'vehicle\', \'school bus\']],\\n",\n', b'       " \'plant\': [[\'plant\', \'cactus\']]}"\n', b'      ]\n', b'     },\n', b'     "execution_count": 7,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# groupby on list\\n",\n', b'    "things = [[\\"animal\\", \\"bear\\"], [\\"animal\\", \\"duck\\"], [\\"vehicle\\", \\"harley\\"], [\\"plant\\", \\"cactus\\"], \\\\\\n",\n', b'    "[\\"vehicle\\", \\"speed boat\\"], [\\"vehicle\\", \\"school bus\\"]]\\n",\n', b'    "\\n",\n', b'    "dic = {}\\n",\n', b'    "f = lambda x: x[0]\\n",\n', b'    "for key, group in groupby(things, f):\\n",\n', b'    "    dic[key] = list(group)\\n",\n', b'    "dic"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 8,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       " ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 24: Linked lists"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "A linked list is a collection of nodes, each made up of a reference and a value. Nodes are strung together into a\\n",\n', b'    "sequence using their references. Linked lists can be used to implement more complex data structures like lists,\\n",\n', b'    "stacks, queues, and associative arrays."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Single linked list example"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stderr",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "<>:76: SyntaxWarning: \\"is\\" with a literal. Did you mean \\"==\\"?\\n",\n', b'      "<>:76: SyntaxWarning: \\"is\\" with a literal. Did you mean \\"==\\"?\\n",\n', b'      "<ipython-input-2-4bfe89c7e618>:76: SyntaxWarning: \\"is\\" with a literal. Did you mean \\"==\\"?\\n",\n', b'      "  if position is 0:\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "class Node:\\n",\n', b'    "    def __init__(self, val):\\n",\n', b'    "        self.data = val\\n",\n', b'    "        self.next = None\\n",\n', b'    "    def getData(self):\\n",\n', b'    "        return self.data\\n",\n', b'    "    def getNext(self):\\n",\n', b'    "        return self.next\\n",\n', b'    "    def setData(self, val):\\n",\n', b'    "        self.data = val\\n",\n', b'    "    def setNext(self, val):\\n",\n', b'    "        self.next = val\\n",\n', b'    "        \\n",\n', b'    "\\n",\n', b'    "class LinkedList:\\n",\n', b'    "    def __init__(self):\\n",\n', b'    "        self.head = None\\n",\n', b'    "    def isEmpty(self):\\n",\n', b'    "        \\"\\"\\"Check if the list is empty\\"\\"\\"\\n",\n', b'    "        return self.head is None\\n",\n', b'    "    def add(self, item):\\n",\n', b'    "        \\"\\"\\"Add the item to the list\\"\\"\\"\\n",\n', b'    "        new_node = Node(item)\\n",\n', b'    "        new_node.setNext(self.head)\\n",\n', b'    "        self.head = new_node\\n",\n', b'    "    def size(self):\\n",\n', b'    "        \\"\\"\\"Return the length/size of the list\\"\\"\\"\\n",\n', b'    "        count = 0\\n",\n', b'    "        current = self.head\\n",\n', b'    "        while current is not None:\\n",\n', b'    "            count += 1\\n",\n', b'    "            current = current.getNext()\\n",\n', b'    "            return count\\n",\n', b'    "    def search(self, item):\\n",\n', b'    "        \\"\\"\\"Search for item in list. If found, return True. If not found, return False\\"\\"\\"\\n",\n', b'    "        current = self.head\\n",\n', b'    "        found = False\\n",\n', b'    "        while current is not None and not found:\\n",\n', b'    "            if current.getData() is item:\\n",\n', b'    "                found = True\\n",\n', b'    "            else:\\n",\n', b'    "                current = current.getNext()\\n",\n', b'    "        return found\\n",\n', b'    "    def remove(self, item):\\n",\n', b'    "        \\"\\"\\"Remove item from list. If item is not found in list, raise ValueError\\"\\"\\"\\n",\n', b'    "        current = self.head\\n",\n', b'    "        previous = None\\n",\n', b'    "        found = False\\n",\n', b'    "        while current is not None and not found:\\n",\n', b'    "            if current.getData() is item:\\n",\n', b'    "                found = True\\n",\n', b'    "            else:\\n",\n', b'    "                previous = current\\n",\n', b'    "                current = current.getNext()\\n",\n', b'    "        if found:\\n",\n', b'    "            if previous is None:\\n",\n', b' ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 26: Filter"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "raw",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Parameter Details\\n",\n', b'    "function     callable that determines the condition or None then use the identity function for filtering (positionalonly)\\n",\n', b'    "iterable     iterable that will be filtered (positional-only)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Basic use of filter"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "To filter discards elements of a sequence based on some criteria:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "<filter at 0x1a7964525b0>"\n', b'      ]\n', b'     },\n', b'     "execution_count": 2,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "names = [\'Fred\', \'Wilma\', \'Barney\']\\n",\n', b'    "def long_name(name):\\n",\n', b'    "    return len(name) > 5\\n",\n', b'    "\\n",\n', b'    "filter(long_name, names) ## will return iterator"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'Barney\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 4,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "list(filter(long_name, names))"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 3,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'Barney\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 3,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "[name for name in names if len(name) > 5]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 7,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "<generator object <genexpr> at 0x000001A7965387B0>"\n', b'      ]\n', b'     },\n', b'     "execution_count": 7,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "(name for name in names if len(name) > 5) # equivalent generator expression"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 8,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[\'Barney\']"\n', b'      ]\n', b'     },\n', b'     "execution_count": 8,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "list((name for name in names if len(name) > 5))"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Filter without function"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "If the function parameter is None, then the identity function will be used:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 9,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "[1, 2, \'a\']"\n', b'      ]\n', b'     },\n', b'     "executio ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 27: Heapq"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Largest and smallest items in a collection"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "To find the largest items in a collection, heapq module has a function called nlargest, we pass it two arguments, the\\n",\n', b'    "first one is the number of items that we want to retrieve, the second one is the collection name:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[200, 150, 100, 50]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "import heapq\\n",\n', b'    "numbers = [1, 4, 2, 100, 20, 50, 32, 200, 150, 8] \\n",\n', b'    "print(heapq.nlargest(4, numbers)) # return four largest elements"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 3,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[1, 2, 4, 8]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "print(heapq.nsmallest(4, numbers)) # return n smallest elemets"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Both nlargest and nsmallest functions take an optional argument (key parameter) for complicated data\\n",\n', b'    "structures. The following example shows the use of age property to retrieve the oldest and the youngest people\\n",\n', b'    "from people dictionary"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[{\'firstname\': \'John\', \'lastname\': \'Roe\', \'age\': 45}, {\'firstname\': \'John\', \'lastname\': \'Doe\', \'age\': 30}]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "people = [\\n",\n', b'    "{\'firstname\': \'John\', \'lastname\': \'Doe\', \'age\': 30},\\n",\n', b'    "{\'firstname\': \'Jane\', \'lastname\': \'Doe\', \'age\': 25},\\n",\n', b'    "{\'firstname\': \'Janie\', \'lastname\': \'Doe\', \'age\': 10},\\n",\n', b'    "{\'firstname\': \'Jane\', \'lastname\': \'Roe\', \'age\': 22},\\n",\n', b'    "{\'firstname\': \'Johnny\', \'lastname\': \'Doe\', \'age\': 12},\\n",\n', b'    "{\'firstname\': \'John\', \'lastname\': \'Roe\', \'age\': 45}\\n",\n', b'    "]\\n",\n', b'    "oldest = heapq.nlargest(2, people, key=lambda s: s[\'age\'])\\n",\n', b'    "print(oldest)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 5,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "name": "stdout",\n', b'     "output_type": "stream",\n', b'     "text": [\n', b'      "[{\'firstname\': \'Janie\', \'lastname\': \'Doe\', \'age\': 10}]\\n"\n', b'     ]\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "youngest = heapq.nsmallest(1, people, key=lambda s: s[\'age\'])\\n",\n', b'    "print(youngest)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "## Smallest item in a collection"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "The most interesting property of a heap is that its smallest element is always the first element: heap[0]"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 6,\n ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "# Chapter 28: Tuple"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "A tuple is an immutable list of values. Tuples are one of Python\'s simplest and most common collection types, and\\n",\n', b'    "can be created with the comma operator (value = 1, 2, 3)."\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "markdown",\n', b'   "metadata": {},\n', b'   "source": [\n', b'    "Syntactically, a tuple is a comma-separated list of values:"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "(\'a\', \'b\', \'c\', \'d\', \'e\')"\n', b'      ]\n', b'     },\n', b'     "execution_count": 1,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "t = \'a\', \'b\', \'c\', \'d\', \'e\'\\n",\n', b'    "t"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 2,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "(\'a\', \'b\', \'c\', \'d\', \'e\')"\n', b'      ]\n', b'     },\n', b'     "execution_count": 2,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "#Although not necessary, it is common to enclose tuples in parentheses:\\n",\n', b'    "t = (\'a\', \'b\', \'c\', \'d\', \'e\')\\n",\n', b'    "t"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 4,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "tuple"\n', b'      ]\n', b'     },\n', b'     "execution_count": 4,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# Create an empty tuple with parentheses:\\n",\n', b'    "t0 = ()\\n",\n', b'    "type(t0)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 6,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "tuple"\n', b'      ]\n', b'     },\n', b'     "execution_count": 6,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# To create a tuple with a single element, you have to include a final comma:\\n",\n', b'    "t1 = \'a\',\\n",\n', b'    "type(t1)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 8,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "str"\n', b'      ]\n', b'     },\n', b'     "execution_count": 8,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "# if there is only one elemet and you do\'nt put comma at end the it wil not be a tupe\\n",\n', b'    "t1 = \'a\'\\n",\n', b'    "type(t1)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 9,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "str"\n', b'      ]\n', b'     },\n', b'     "execution_count": 9,\n', b'     "metadata": {},\n', b'     "output_type": "execute_result"\n', b'    }\n', b'   ],\n', b'   "source": [\n', b'    "t2 = (\'a\')#string\\n",\n', b'    "type(t2)"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 10,\n', b'   "metadata": {},\n', b'   "outputs": [\n', b'    {\n', b'     "data": {\n', b'      "text/plain": [\n', b'       "tuple"\n', b'      ...
# ...
# [b'{\r\n', b' "cells": [\r\n', b'  {\r\n', b'   "cell_type": "markdown",\r\n', b'   "metadata": {},\r\n', b'   "source": [\r\n', b'    "# Chapter 8: Set"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "markdown",\r\n', b'   "metadata": {},\r\n', b'   "source": [\r\n', b'    "## Set Operations"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 1,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "{3, 4, 5}"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 1,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "# Intersecction function\\n",\r\n', b'    "{1, 2, 3, 4, 5}.intersection({3, 4, 5, 6}) # {3,4,5}\\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 3,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "{3, 4, 5}"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 3,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "# Intersecction uinsg operator\\n",\r\n', b'    "{1, 2, 3, 4, 5} & {3, 4, 5, 6} # {3,4,5}"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 4,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "{1, 2, 3, 4, 5, 6, 8}"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 4,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "# Union using Function\\n",\r\n', b'    "{1, 2, 3, 4, 5}.union({3, 4, 5, 6,8}) #{1,2,3,4,5,6,8}"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 5,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "{1, 2, 3, 4, 5, 6, 8}"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 5,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "# Union using Operator\\n",\r\n', b'    "{1, 2, 3, 4, 5} | {3, 4, 5, 6,8} #{1,2,3,4,5,6,8}"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 7,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "{1, 4}"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 7,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "# Difference uisng function\\n",\r\n', b'    "{1, 2, 3, 4}.difference({2, 3, 5}) # {1,4}"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 8,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "{1, 4}"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 8,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "# Difference uisng operator\\n",\r\n', b'    "{1, 2, 3, 4}-{2, 3, 5} # {1,4}"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 10,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "{1, 4, 5}"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 10,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r ...
# [b'{\r\n', b' "cells": [\r\n', b'  {\r\n', b'   "cell_type": "markdown",\r\n', b'   "metadata": {},\r\n', b'   "source": [\r\n', b'    "# Chapter 9: Simple Mathematical Operators\\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "markdown",\r\n', b'   "metadata": {},\r\n', b'   "source": [\r\n', b'    "Python does common mathematical operators on its own, including integer and \xef\xac\x82oat division, multiplication, exponentiation, addition, and subtraction. The math module (included in all standard Python versions) o\xef\xac\x80ers expanded functionality like trigonometric functions, root operations, logarithms, and many more. \\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "markdown",\r\n', b'   "metadata": {},\r\n', b'   "source": [\r\n', b'    "### Division\\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 1,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "1.5"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 1,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "a, b, c, d, e = 3, 2, 2.0, -3, 10\\n",\r\n', b'    "\\n",\r\n', b'    "a / b       # = 1\\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 2,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "1.5"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 2,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "a / c                \\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 3,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "-1.5"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 3,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "d / b                 \\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 4,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "0.6666666666666666"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 4,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "b / a                 \\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 6,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "1.0"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 6,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "b/ c               \\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 7,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "1.5"\r\n', b'      ]\r\n', b'     },\r\n', b'     "execution_count": 7,\r\n', b'     "metadata": {},\r\n', b'     "output_type": "execute_result"\r\n', b'    }\r\n', b'   ],\r\n', b'   "source": [\r\n', b'    "float(a) / b           # = 1.5  \\n"\r\n', b'   ]\r\n', b'  },\r\n', b'  {\r\n', b'   "cell_type": "code",\r\n', b'   "execution_count": 8,\r\n', b'   "metadata": {},\r\n', b'   "outputs": [\r\n', b'    {\r\n', b'     "data": {\r\n', b'      "text/plain": [\r\n', b'       "1.5"\r\n', b'      ...
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 3,\n', b'   "metadata": {},\n', b'   "outputs": [],\n', b'   "source": [\n', b'    "def say_hello():\\n",\n', b'    "    print(\\"Hello!\\")"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": null,\n', b'   "metadata": {},\n', b'   "outputs": [],\n', b'   "source": []\n', b'  }\n', b' ],\n', b' "metadata": {\n', b'  "kernelspec": {\n', b'   "display_name": "Python 3",\n', b'   "language": "python",\n', b'   "name": "python3"\n', b'  },\n', b'  "language_info": {\n', b'   "codemirror_mode": {\n', b'    "name": "ipython",\n', b'    "version": 3\n', b'   },\n', b'   "file_extension": ".py",\n', b'   "mimetype": "text/x-python",\n', b'   "name": "python",\n', b'   "nbconvert_exporter": "python",\n', b'   "pygments_lexer": "ipython3",\n', b'   "version": "3.8.3"\n', b'  }\n', b' },\n', b' "nbformat": 4,\n', b' "nbformat_minor": 4\n', b'}\n']
# [b'{\n', b' "cells": [\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": 1,\n', b'   "metadata": {},\n', b'   "outputs": [],\n', b'   "source": [\n', b'    "def say_hello():\\n",\n', b'    "    print(\\"Hello!\\")"\n', b'   ]\n', b'  },\n', b'  {\n', b'   "cell_type": "code",\n', b'   "execution_count": null,\n', b'   "metadata": {},\n', b'   "outputs": [],\n', b'   "source": []\n', b'  }\n', b' ],\n', b' "metadata": {\n', b'  "kernelspec": {\n', b'   "display_name": "Python 3",\n', b'   "language": "python",\n', b'   "name": "python3"\n', b'  },\n', b'  "language_info": {\n', b'   "codemirror_mode": {\n', b'    "name": "ipython",\n', b'    "version": 3\n', b'   },\n', b'   "file_extension": ".py",\n', b'   "mimetype": "text/x-python",\n', b'   "name": "python",\n', b'   "nbconvert_exporter": "python",\n', b'   "pygments_lexer": "ipython3",\n', b'   "version": "3.8.3"\n', b'  }\n', b' },\n', b' "nbformat": 4,\n', b' "nbformat_minor": 4\n', b'}\n']
# [b'# Python\r\n', b'Here we will learn python step by step.\r\n', b'# Contents\r\n', b'## Chapter 1: Getting started with Python Language\r\n', b'## Chapter 2: Python Data Types\r\n', b'## Chapter 3: Indentation\r\n', b'## Chapter 4: Comments and Documentation\r\n', b'## Chapter 5: Date and Time\r\n', b'## Chapter 6: Date Formatting\r\n', b'## Chapter 7: Enum\r\n', b'## Chapter 8: Set\r\n', b'## Chapter 9: Simple Mathematical Operators\r\n', b'## Chapter 10: Bitwise Operators\r\n', b'## Chapter 11: Boolean Operators\r\n', b'## Chapter 12: Operator Precedence\r\n', b'## Chapter 13: Variable Scope and Binding\r\n', b'## Chapter 14: Conditionals\r\n', b'## Chapter 15: Comparisons\r\n', b'## Chapter 16: Loops\r\n', b'## Chapter 17: Arrays\r\n', b'## Chapter 18: Multidimensional arrays\r\n', b'## Chapter 19: Dictionary\r\n', b'## Chapter 20: List\r\n', b'## Chapter 21: List comprehensions\r\n', b'## Chapter 22: List slicing (selecting parts of lists)\r\n', b'## Chapter 23: groupby()\r\n', b'## Chapter 24: Linked lists\r\n', b'## Chapter 25: Linked List Node\r\n', b'## Chapter 26: Filter\r\n', b'## Chapter 27: Heapq\r\n', b'## Chapter 28: Tuple\r\n', b'## Chapter 29: Basic Input and Output\r\n', b'## Chapter 30: Files & Folders I/O\r\n', b'## Chapter 31: os.path\r\n', b'## Chapter 32: Iterables and Iterators\r\n', b'## Chapter 33: Functions\r\n', b'## Chapter 34: Defining functions with list arguments\r\n', b'## Chapter 35: Functional Programming in Python\r\n', b'## Chapter 36: Partial functions\r\n', b'## Chapter 37: Decorators\r\n', b'## Chapter 38: Classes\r\n', b'## Chapter 39: Metaclasses\r\n', b'## Chapter 40: String Formatting\r\n', b'## Chapter 41: String Methods\r\n', b'## Chapter 42: Using loops within functions\r\n', b'## Chapter 43: Importing modules\r\n', b'## Chapter 44: Di\xee\x80\xa3erence between Module and Package\r\n', b'## Chapter 45: Math Module\r\n', b'## Chapter 46: Complex math\r\n', b'## Chapter 47: Collections module\r\n', b'## Chapter 48: Operator module\r\n', b'## Chapter 49: JSON Module\r\n', b'## Chapter 50: Sqlite3 Module\r\n', b'## Chapter 51: The os Module\r\n', b'## Chapter 52: The locale Module\r\n', b'## Chapter 53: Itertools Module\r\n', b'## Chapter 54: Asyncio Module\r\n', b'## Chapter 55: Random module\r\n', b'## Chapter 56: Functools Module\r\n', b'## Chapter 57: The dis module\r\n', b'## Chapter 58: The base64 Module\r\n', b'## Chapter 59: Queue Module\r\n', b'## Chapter 60: Deque Module\r\n', b'## Chapter 61: Webbrowser Module\r\n', b'## Chapter 62: tkinter\r\n', b'## Chapter 63: pyautogui module\r\n', b'## Chapter 64: Indexing and Slicing\r\n', b'## Chapter 65: Plotting with Matplotlib\r\n', b'## Chapter 66: graph-tool\r\n', b'## Chapter 67: Generators\r\n', b'## Chapter 68: Reduce\r\n', b'## Chapter 69: Map Function\r\n', b'## Chapter 70: Exponentiation\r\n', b'## Chapter 71: Searching\r\n', b'## Chapter 72: Sorting, Minimum and Maximum\r\n', b'## Chapter 73: Counting\r\n', b'## Chapter 74: The Print Function\r\n', b'## Chapter 75: Regular Expressions (Regex)\r\n', b'## Chapter 76: Copying data\r\n', b'## Chapter 77: Context Managers (\xe2\x80\x9cwith\xe2\x80\x9d Statement)\r\n', b'## Chapter 78: The __name__ special variable\r\n', b'## Chapter 79: Checking Path Existence and Permissions\r\n', b'## Chapter 80: Creating Python packages\r\n', b'## Chapter 81: Usage of "pip" module: PyPI Package Manager\r\n', b'## Chapter 82: pip: PyPI Package Manager\r\n', b'## Chapter 83: Parsing Command Line arguments\r\n', b'## Chapter 84: Subprocess Library\r\n', b'## Chapter 85: setup.py\r\n', b'## Chapter 86: Recursion\r\n', b'## Chapter 87: Type Hints\r\n', b'## Chapter 88: Exceptions\r\n', b'## Chapter 89: Raise Custom Errors / Exceptions\r\n', b'## Chapter 90: Commonwealth Exceptions\r\n', b'## Chapter 91: urllib\r\n', b'## Chapter 92: Web scraping with Python\r\n', b'## Chapter 93: HTML Parsing\r\n', b'## Chapter 94: Manipulating XML\r\n', b'## Chapter 95: Python Requests Post\r\n', b'## Chapter  ...
# [b'tomato\r\n', b'pasta\r\n', b'garlic']
# [b'Shipping Lists \n', b'for testing\n']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-5615f4bafae5> in <module>
#       3     for filename in files:
#       4         #print(root, filename)
# ----> 5         with open(filename ,'rb') as file:
#       6             lines = file.readlines()
#       7             print(lines)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.MERGE_MSG.swp'

# %%
import os

for root, folders, files in os.walk('.'):
    for filename in files:
        #print(root, filename)
        with open(filename ,'rb') as file:
            lines = file.read()
            print(lines)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-5603bba505d7> in <module>
#       4     for filename in files:
#       5         #print(root, filename)
# ----> 6         with open(filename ,'rb') as file:
#       7             lines = file.read()
#       8             print(lines)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.MERGE_MSG.swp'

# %% [markdown]
# ## Writing to a file

# %%
with open('myfile.txt', 'w') as f:
    f.write("Line 1")
    f.write("Line 2")
    f.write("Line 3")
    f.write("Line 4")

# %%
with open ('myfile.txt','r') as f:
    print(f.read())
# Out:
# Line 1Line 2Line 3Line 4

# %%
with open('myfile.txt', 'w') as f:
    f.write("Line 1\n")
    f.write("Line 2\n")
    f.write("Line 3\n")
    f.write("Line 4\n")

# %%
with open ('myfile.txt','r') as f:
    print(f.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4

# %% [markdown]
# If you want to specify an encoding, you simply add the encoding parameter to the open function:

# %%
with open('my_file.txt', 'w', encoding='utf-8') as f:
    f.write('utf-8 text')

# %%
with open ('my_file.txt','r') as f:
    print(f.read())
# Out:
# utf-8 text

# %%
with open('fred.txt', 'w') as outfile:
    s = "I'm Not Dead Yet!"
    print(s) # writes to stdout
    print(s, file = outfile)
# Out:
# I'm Not Dead Yet!

# %%
with open('fred.txt', 'r') as outfile:
    print(outfile.read()) # writes to stdout
# Out:
# I'm Not Dead Yet!

# %% [markdown]
# ## Check whether a file or path exists

# %%
import errno
try:
     # pass valid path
    path= 'myfile.txt'
    with open(path) as f:
        pass
except IOError as e:
    if e.errno != errno.ENOENT:
        raise
    # No such file or directory

# %%
import errno
try:
    # pass invalid path
    path= 'test.txt'
    with open(path) as f:
        print('directory exist')
except IOError as e:
    if e.errno != errno.ENOENT:
        print('no such directory exist')
    # No such file or directory

# %% [markdown]
# ## Random File Access Using mmap

# %% [markdown]
# Using the mmap module allows the user to randomly access locations in a file by mapping the file into memory. This
# is an alternative to using normal file operations.

# %%
import mmap
with open('shoppinglist.txt', 'r') as fd:
    # 0: map the whole file
    mm = mmap.mmap(fd.fileno(), 0)
    # print characters at indices 5 through 10
    print (mm[5:10])
    # print the line starting from mm's current position
    print (mm.readline())
    # write a character to the 5th index
    mm[5] = 'a'
    # return mm's position to the beginning of the file
    mm.seek(0)
    # close the mmap object
    mm.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-10-330811880a40> in <module>
#       2 with open('shoppinglist.txt', 'r') as fd:
#       3     # 0: map the whole file
# ----> 4     mm = mmap.mmap(fd.fileno(), 0)
#       5     # print characters at indices 5 through 10
#       6     print (mm[5:10])
#
# PermissionError: [WinError 5] Access is denied

# %% [markdown]
# ## Replacing text in a file

# %%
import fileinput
replacements = {'tomato': 'tomato updated',
'garlic': 'garlic updated'}
for line in fileinput.input('shoppinglist.txt', inplace=True):
    for search_for in replacements:
        replace_with = replacements[search_for]
        line = line.replace(search_for, replace_with)
    print(line, end='')

# %%
with open ('shoppinglist.txt','r') as file:
    print(file.read())
# Out:
# tomato updated
# pasta
# garlic updated

# %% [markdown]
# ## Checking if a file is empty

# %%
import os
os.stat(path_to_file).st_size == 0

# %%
#or
import os
os.path.getsize(path_to_file) > 0

# %% [markdown]
# However, both will throw an exception if the file does not exist. To avoid having to catch such an error, do this:

# %%
import os
def is_empty_file(fpath):
    return os.path.isfile(fpath) and os.path.getsize(fpath) > 0

# %% [markdown]
# ##  Read a file between a range of lines

# %% [markdown]
# So let's suppose you want to iterate only between some specific lines of a file

# %%
import itertools
with open('shoppinglist.txt', 'r') as f:
    result =[line for line in itertools.islice(f, 0, 10)]
    print(result)
    #for line in itertools.islice(f, 0, 10):
      #print(line)
# Out:
# ['tomato updated\n', 'pasta\n', 'garlic updated']

# %% [markdown]
# ## Copy a directory tree

# %%
# sensitive code 
# careful while paly with shutil
#The destination directory must not exist already.
import shutil
source='G:\c++'
destination='E:\\c++'
shutil.copytree(source, destination)
# Out:
# 'E:\\c++'

# %% [markdown]
# ## Copying contents of one file to a diffrent file

# %%
with open('myfile.txt', 'r') as in_file, open('my_file.txt', 'w') as out_file:
    for line in in_file:
        out_file.write(line)

# %%
with open('my_file.txt','r') as file:
    print(file.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4

# %%
with open('myfile.txt','r') as file:
    print(file.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4

# %%
#Using the shutil module
import shutil
source ='myfile.txt'
destination= 'myfilecopy.txt'
shutil.copyfile(source,destination)
# Out:
# 'myfilecopy.txt'

# %%
with open('myfilecopy.txt','r') as file:
    print(file.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
